# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import random
from sklearn.utils import shuffle
import shutil
from skimage.transform import resize
from PIL import Image
from IPython.display import display

# %%
def get_stats(df, suffix=None):
    """Provides a quick summary of a dataframe."""
    try:
        print(f"DF shape: {df.shape}")
        print(f"# Patients: {df.empi_anon.nunique()}")
        print(f"# Exams: {df.acc_anon.nunique()}")
        print(f"# Images dicom: {df.anon_dicom_path.nunique()}\n")

    except Exception as e:
        print(e)

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 500)



## Read clinical and metadata rows
magview_path = '/content/EMBED_OpenData_clinical_reduced.csv'
metadata_path = '/content/EMBED_OpenData_metadata_reduced.csv'

#Load metadata
df_clinical = pd.read_csv(magview_path)
df_metadata = pd.read_csv(metadata_path)

df_clinical['procdate_anon'] = pd.to_datetime(df_clinical['procdate_anon'], errors='coerce')

df_clinical['study_date_anon'] = pd.to_datetime(df_clinical['study_date_anon'], errors='coerce')
df_metadata['study_date_anon'] = pd.to_datetime(df_metadata['study_date_anon'], errors='coerce')

#df_metadata = df_metadata.sort_values(by=['study_date_anon']).reset_index(drop=True)
df_metadata = df_metadata.sort_values(by=['empi_anon', 'study_date_anon']).reset_index(drop=True)
df_clinical = df_clinical.sort_values(by=['empi_anon', 'study_date_anon']).reset_index(drop=True)
df_metadata.to_csv("/content/EMBED_OpenData_metadata_reduced_sorted.csv", index=False)
df_clinical.to_csv("/content/EMBED_OpenData_clinical_reduced_sorted.csv", index=False)

print("clinical data input")
get_stats(df_clinical)
print("metadata data input")
get_stats(df_metadata)

display(df_metadata)
display(df_clinical)
# Out:
# <ipython-input-2-4a52487af88d>:22: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_clinical = pd.read_csv(magview_path)
# <ipython-input-2-4a52487af88d>:23: DtypeWarning: Columns (27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_metadata = pd.read_csv(metadata_path)
# clinical data input
# DF shape: (81776, 21)
# # Patients: 23253
# # Exams: 72770
# 'DataFrame' object has no attribute 'anon_dicom_path'
# metadata data input
# DF shape: (480323, 29)
# # Patients: 23256
# # Exams: 72770
# # Images dicom: 480323
#         Unnamed: 0  empi_anon          acc_anon  cohort_num study_date_anon  \
# 0            22721   10000879  6992096043050201           1      2018-02-16
# 1            22723   10000879  6992096043050201           1      2018-02-16
# 2            22725   10000879  6992096043050201           1      2018-02-16
# 3            22726   10000879  6992096043050201           1      2018-02-16
# 4            22727   10000879  6992096043050201           1      2018-02-16
# ...            ...        ...               ...         ...             ...
# 480318       22850   99999564  4369225803558884           1      2017-04-25
# 480319       22849   99999564  8832872399780580           1      2019-02-27
# 480320       22851   99999564  8832872399780580           1      2019-02-27
# 480321       22852   99999564  8832872399780580           1      2019-02-27
# 480322       22854   99999564  8832872399780580           1      2019-02-27
#
#                                 StudyDescription SeriesDescription  \
# 0       MG Screen Bilat w/Tomo/CAD Stnd Protocol             R MLO
# 1       MG Screen Bilat w/Tomo/CAD Stnd Protocol             L MLO
# 2       MG Screen Bilat w/Tomo/CAD Stnd Protocol              R CC
# 3       MG Screen Bilat w/Tomo/CAD Stnd Protocol      L MLO C-View
# 4       MG Screen Bilat w/Tomo/CAD Stnd Protocol       R CC C-View
# ...                                          ...               ...
# 480318  MG Screen Bilat w/Tomo/CAD Stnd Protocol             L MLO
# 480319  MG Screen Bilat w/Tomo/CAD Stnd Protocol              L CC
# 480320  MG Screen Bilat w/Tomo/CAD Stnd Protocol             L MLO
# 480321  MG Screen Bilat w/Tomo/CAD Stnd Protocol              R CC
# 480322  MG Screen Bilat w/Tomo/CAD Stnd Protocol             R MLO
#
#        FinalImageType ImageLateralityFinal ViewPosition  spot_mag  \
# 0                  2D                    R          MLO       NaN
# 1                  2D                    L          MLO       NaN
# 2                  2D                    R           CC       NaN
# 3               cview                    L          MLO       NaN
# 4               cview                    R           CC       NaN
# ...               ...                  ...          ...       ...
# 480318             2D                    L          MLO       NaN
# 480319             2D                    L           CC       NaN
# 480320             2D                    L          MLO       NaN
# 480321             2D                    R           CC       NaN
# 480322             2D                    R          MLO       NaN
#
#                                           anon_dicom_path  num_roi ROI_coords  \
# 0       /mnt/NAS2/mammo/anon_dicom/cohort_1/10000879/1...        0         ()
# 1       /mnt/NAS2/mammo/anon_dicom/cohort_1/10000879/1...        0         ()
# 2       /mnt/NAS2/mammo/anon_dicom/cohort_1/10000879/1...        0         ()
# 3       /mnt/NAS2/mammo/anon_dicom/cohort_1/10000879/1...        0         ()
# 4       /mnt/NAS2/mammo/anon_dicom/cohort_1/10000879/1...        0         ()
# ...                                                   ...      ...        ...
# 480318  /mnt/NAS2/mammo/anon_dicom/cohort_1/99999564/1...        0         ()
# 480319  /mnt/NAS2/mammo/anon_dicom/cohort_1/99999564/1...        0         ()
# 480320  /mnt/NAS2/mammo/anon_dicom/cohort_1/99999564/1...        0         ()
# 480321  /mnt/NAS2/mammo/anon_dicom/cohort_1/99999564/1...        0         ()
# 480322  /mnt/NAS2/mammo/anon_dicom/cohort_1/99999564/1...        0         ()
#
#        SRC_DST match_level   Manufacturer ManufacturerModelName PatientSex  \
# 0           []          []  HOLOGIC, Inc.    Selenia Dimensions          F
# 1           []          []  HOLOGIC, Inc.    Selenia Dimensions          F
# 2           []          []  HOLOGIC, Inc.    Selenia Dimensions          F
# 3           []          []  HOLOGIC, Inc.    Selenia Dimensions          F
# 4           []          []  HOLOGIC, Inc.    Selenia Dimensions          F
# ...        ...         ...            ...                   ...        ...
# 480318      []          []  HOLOGIC, Inc.    Selenia Dimensions          F
# 480319      []          []  HOLOGIC, Inc.    Selenia Dimensions          F
# 480320      []          []  HOLOGIC, Inc.    Selenia Dimensions          F
# 480321      []          []  HOLOGIC, Inc.    Selenia Dimensions          F
# 480322      []          []  HOLOGIC, Inc.    Selenia Dimensions          F
#
#          ProtocolName  SeriesNumber  SeriesTime           StudyID  \
# 0       R MLO ComboHD      71300000    101829.0   MG Screen Bilat
# 1       L MLO ComboHD      71300000    102019.0   MG Screen Bilat
# 2        R CC ComboHD      71300000    101405.0   MG Screen Bilat
# 3       L MLO ComboHD      71300000    102019.0   MG Screen Bilat
# 4        R CC ComboHD      71300000    101405.0   MG Screen Bilat
# ...               ...           ...         ...               ...
# 480318    L MLO Combo      71300000    135119.0  MG Screening Dig
# 480319     L CC Combo      71300000     83056.0   MG Screen Bilat
# 480320    L MLO Combo      71300000     83213.0   MG Screen Bilat
# 480321     R CC Combo      71300000     82918.0   MG Screen Bilat
# 480322    R MLO Combo      71300000     83327.0   MG Screen Bilat
#
#        WindowCenter WindowWidth  has_pix_array  category VOILUTFunction  \
# 0            2047.0      4096.0          False  no image            NaN
# 1            2047.0      4096.0          False  no image            NaN
# 2            2047.0      4096.0          False  no image            NaN
# 3             540.0       580.0          False  no image            NaN
# 4             540.0       580.0          False  no image            NaN
# ...             ...         ...            ...       ...            ...
# 480318       2047.0      4096.0          False  no image            NaN
# 480319       2047.0      4096.0          False  no image            NaN
# 480320       2047.0      4096.0          False  no image            NaN
# 480321       2047.0      4096.0          False  no image            NaN
# 480322       2047.0      4096.0          False  no image            NaN
#
#        WindowCenterWidthExplanation
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 480318                          NaN
# 480319                          NaN
# 480320                          NaN
# 480321                          NaN
# 480322                          NaN
#
# [480323 rows x 29 columns]
#        Unnamed: 0  empi_anon          acc_anon  \
# 0           31489   10000879  6992096043050201
# 1           10198   10009146  4190527469809995
# 2           20474   10015693  1334581155737139
# 3           31427   10015693  2281263876413228
# 4           42831   10019048  6465041439526495
# ...           ...        ...               ...
# 81771       10363   99996622  5582628875236699
# 81772       10364   99996622  5582628875236699
# 81773       21119   99996622  9655172659462321
# 81774       25708   99999564  4369225803558884
# 81775       31493   99999564  8832872399780580
#
#                                            desc  numfind side asses  \
# 0      MG Screen Bilat w/Tomo/CAD Stnd Protocol        1  NaN     N
# 1      MG Screen Bilat w/Tomo/CAD Stnd Protocol        1  NaN     N
# 2      MG Screen Bilat w/Tomo/CAD Stnd Protocol        1    L     A
# 3      MG Screen Bilat w/Tomo/CAD Stnd Protocol        1  NaN     N
# 4                        MG Screening Bilateral        1  NaN     N
# ...                                         ...      ...  ...   ...
# 81771  MG Screen Bilat w/Tomo/CAD Stnd Protocol        1    B     B
# 81772  MG Screen Bilat w/Tomo/CAD Stnd Protocol        2    R     B
# 81773  MG Screen Bilat w/Tomo/CAD Stnd Protocol        1  NaN     N
# 81774  MG Screen Bilat w/Tomo/CAD Stnd Protocol        1  NaN     N
# 81775  MG Screen Bilat w/Tomo/CAD Stnd Protocol        1  NaN     N
#
#        tissueden bside GENDER_DESC                                  RACE_DESC  \
# 0            3.0   NaN      Female                                   Multiple
# 1            4.0   NaN      Female         Unknown, Unavailable or Unreported
# 2            2.0   NaN      Female                         Caucasian or White
# 3            2.0   NaN      Female                         Caucasian or White
# 4            4.0   NaN      Female  Native Hawaiian or Other Pacific Islander
# ...          ...   ...         ...                                        ...
# 81771        3.0   NaN      Female                 African American  or Black
# 81772        3.0   NaN      Female                 African American  or Black
# 81773        3.0   NaN      Female                 African American  or Black
# 81774        3.0   NaN      Female                         Caucasian or White
# 81775        3.0   NaN      Female                         Caucasian or White
#
#                       ETHNIC_GROUP_DESC MARITAL_STATUS_DESC  age_at_study  \
# 0                          Not Recorded        Not Recorded     41.879026
# 1      Unreported, Unknown, Unavailable        Not Recorded     38.924824
# 2                Non-Hispanic or Latino            Divorced     65.167663
# 3                Non-Hispanic or Latino            Divorced     67.407271
# 4                    Hispanic or Latino             Married     45.646386
# ...                                 ...                 ...           ...
# 81771            Non-Hispanic or Latino            Divorced     77.288377
# 81772            Non-Hispanic or Latino            Divorced     77.288377
# 81773            Non-Hispanic or Latino            Divorced     79.152892
# 81774            Non-Hispanic or Latino             Married     73.573037
# 81775            Non-Hispanic or Latino             Married     75.415649
#
#       study_date_anon procdate_anon  cohort_num  path_severity  total_L_find  \
# 0          2018-02-16           NaT           1            NaN           0.0
# 1          2014-07-04           NaT           1            NaN           0.0
# 2          2015-10-11           NaT           1            NaN           1.0
# 3          2018-01-06           NaT           1            NaN           0.0
# 4          2013-03-11           NaT           2            NaN           0.0
# ...               ...           ...         ...            ...           ...
# 81771      2014-07-24           NaT           1            NaN           1.0
# 81772      2014-07-24           NaT           1            NaN           1.0
# 81773      2016-06-04           NaT           1            NaN           0.0
# 81774      2017-04-25           NaT           1            NaN           0.0
# 81775      2019-02-27           NaT           1            NaN           0.0
#
#        total_R_find first_3_zip
# 0               0.0       301.0
# 1               0.0       303.0
# 2               0.0         300
# 3               0.0       300.0
# 4               0.0       301.0
# ...             ...         ...
# 81771           2.0       303.0
# 81772           2.0       303.0
# 81773           0.0         303
# 81774           0.0       300.0
# 81775           0.0       300.0
#
# [81776 rows x 21 columns]

# %%
cancer_images = df_clinical[(df_clinical['asses'] == "K") | (df_clinical['path_severity'].isin([0, 1]))]

cancer_images.to_csv("/content/POSITIVE_GROUP_cancer_img.csv", index=False)

get_stats(cancer_images)
display(cancer_images)
# Out:
# DF shape: (1906, 21)
# # Patients: 763
# # Exams: 1200
# 'DataFrame' object has no attribute 'anon_dicom_path'
#        Unnamed: 0  empi_anon          acc_anon  \
# 60          61749   10065686  8381398024560613
# 111         44090   10119504  5579010047669510
# 112         44089   10119504  9436120411494617
# 113         49206   10119504  9897073854156802
# 169         71140   10173804  7180728150657133
# ...           ...        ...               ...
# 81609       81669   99761210  5735953033883954
# 81610       81670   99761210  5735953033883954
# 81670       57072   99859914  8060289603969136
# 81680       12449   99868531  9090933158477514
# 81690       34674   99868531  2145477352100012
#
#                                            desc  numfind side asses  \
# 60               MG Diagnostic Bilateral w/ CAD        1    R     K
# 111               MG Diagnostic Mammo Bilateral        1    L     S
# 112                          MG Diagnostic Left        1    L     K
# 113               MG Diagnostic Mammo Bilateral        1    L     K
# 169    MG Screen Bilat w/Tomo/CAD Stnd Protocol        1    L     A
# ...                                         ...      ...  ...   ...
# 81609        MG Diagnostic Bilateral w/Tomo/CAD        1    L     A
# 81610        MG Diagnostic Bilateral w/Tomo/CAD        2    L     A
# 81670            MG Diagnostic Bilateral w/ CAD        2    L     S
# 81680                 MG Diagnostic Right w/CAD        1    R     S
# 81690            MG Diagnostic Bilateral w/ CAD        2    R     S
#
#        tissueden bside GENDER_DESC                           RACE_DESC  \
# 60           3.0   NaN      Female                               Asian
# 111          2.0     L      Female  Unknown, Unavailable or Unreported
# 112          2.0   NaN      Female  Unknown, Unavailable or Unreported
# 113          2.0   NaN      Female  Unknown, Unavailable or Unreported
# 169          3.0     L      Female                  Caucasian or White
# ...          ...   ...         ...                                 ...
# 81609        3.0     L      Female                  Caucasian or White
# 81610        3.0     L      Female                  Caucasian or White
# 81670        3.0     L      Female          African American  or Black
# 81680        2.0     R      Female          African American  or Black
# 81690        2.0     R      Female          African American  or Black
#
#             ETHNIC_GROUP_DESC MARITAL_STATUS_DESC  age_at_study  \
# 60     Non-Hispanic or Latino        Not Recorded     57.090837
# 111        Hispanic or Latino            Divorced     72.201346
# 112        Hispanic or Latino            Divorced     72.642149
# 113        Hispanic or Latino            Divorced     73.260916
# 169    Non-Hispanic or Latino             Married     72.888560
# ...                       ...                 ...           ...
# 81609      Hispanic or Latino             Married     53.572626
# 81610      Hispanic or Latino             Married     53.572626
# 81670  Non-Hispanic or Latino              Single     56.740385
# 81680  Non-Hispanic or Latino             Married     66.235446
# 81690  Non-Hispanic or Latino             Married     70.197198
#
#       study_date_anon procdate_anon  cohort_num  path_severity  total_L_find  \
# 60         2016-09-28           NaT           2            NaN           1.0
# 111        2013-01-19    2013-01-20           2            0.0           1.0
# 112        2013-06-29           NaT           2            NaN           1.0
# 113        2014-02-10           NaT           2            NaN           1.0
# 169        2018-08-05    2018-11-10           2            0.0           3.0
# ...               ...           ...         ...            ...           ...
# 81609      2020-03-14    2020-03-28           2            1.0           2.0
# 81610      2020-03-14    2020-03-28           2            1.0           2.0
# 81670      2017-03-19    2017-03-22           2            1.0           2.0
# 81680      2015-06-21    2015-06-28           1            1.0           0.0
# 81690      2019-06-07    2019-06-14           1            1.0           1.0
#
#        total_R_find first_3_zip
# 60              1.0       300.0
# 111             0.0       303.0
# 112             0.0       303.0
# 113             0.0       303.0
# 169             0.0       300.0
# ...             ...         ...
# 81609           1.0       303.0
# 81610           1.0       303.0
# 81670           0.0       301.0
# 81680           2.0       303.0
# 81690           1.0         303
#
# [1906 rows x 21 columns]

# %%
# Ensure the dates are in datetime format
cancer_df = cancer_images.copy()
cancer_df['study_date_anon'] = pd.to_datetime(cancer_df['study_date_anon'])

# Step 1: Find the latest cancer diagnosis date for each patient
latest_diagnosis_dates = (
    cancer_df.groupby('empi_anon')['study_date_anon']
    .max()
    .reset_index()
    .rename(columns={'study_date_anon': 'latest_diagnosed_date'})
)

# Step 2: Merge the latest diagnosis dates back into the cancer dataframe
cancer_df = cancer_df.merge(
    latest_diagnosis_dates,
    on='empi_anon',
    how='left'
)

# Step 3: Replace `diagnosed_date_anon` with the `latest_diagnosed_date`
#cancer_df['study_date_anon'] = cancer_df['latest_diagnosed_date']

# Step 4: Drop the helper column (optional)
#cancer_df.drop(columns=['latest_diagnosed_date'], inplace=True)
display(cancer_df)
print(cancer_df.columns)
# Out:
#       Unnamed: 0  empi_anon          acc_anon  \
# 0          61749   10065686  8381398024560613
# 1          44090   10119504  5579010047669510
# 2          44089   10119504  9436120411494617
# 3          49206   10119504  9897073854156802
# 4          71140   10173804  7180728150657133
# ...          ...        ...               ...
# 1901       81669   99761210  5735953033883954
# 1902       81670   99761210  5735953033883954
# 1903       57072   99859914  8060289603969136
# 1904       12449   99868531  9090933158477514
# 1905       34674   99868531  2145477352100012
#
#                                           desc  numfind side asses  tissueden  \
# 0               MG Diagnostic Bilateral w/ CAD        1    R     K        3.0
# 1                MG Diagnostic Mammo Bilateral        1    L     S        2.0
# 2                           MG Diagnostic Left        1    L     K        2.0
# 3                MG Diagnostic Mammo Bilateral        1    L     K        2.0
# 4     MG Screen Bilat w/Tomo/CAD Stnd Protocol        1    L     A        3.0
# ...                                        ...      ...  ...   ...        ...
# 1901        MG Diagnostic Bilateral w/Tomo/CAD        1    L     A        3.0
# 1902        MG Diagnostic Bilateral w/Tomo/CAD        2    L     A        3.0
# 1903            MG Diagnostic Bilateral w/ CAD        2    L     S        3.0
# 1904                 MG Diagnostic Right w/CAD        1    R     S        2.0
# 1905            MG Diagnostic Bilateral w/ CAD        2    R     S        2.0
#
#      bside GENDER_DESC                           RACE_DESC  \
# 0      NaN      Female                               Asian
# 1        L      Female  Unknown, Unavailable or Unreported
# 2      NaN      Female  Unknown, Unavailable or Unreported
# 3      NaN      Female  Unknown, Unavailable or Unreported
# 4        L      Female                  Caucasian or White
# ...    ...         ...                                 ...
# 1901     L      Female                  Caucasian or White
# 1902     L      Female                  Caucasian or White
# 1903     L      Female          African American  or Black
# 1904     R      Female          African American  or Black
# 1905     R      Female          African American  or Black
#
#            ETHNIC_GROUP_DESC MARITAL_STATUS_DESC  age_at_study  \
# 0     Non-Hispanic or Latino        Not Recorded     57.090837
# 1         Hispanic or Latino            Divorced     72.201346
# 2         Hispanic or Latino            Divorced     72.642149
# 3         Hispanic or Latino            Divorced     73.260916
# 4     Non-Hispanic or Latino             Married     72.888560
# ...                      ...                 ...           ...
# 1901      Hispanic or Latino             Married     53.572626
# 1902      Hispanic or Latino             Married     53.572626
# 1903  Non-Hispanic or Latino              Single     56.740385
# 1904  Non-Hispanic or Latino             Married     66.235446
# 1905  Non-Hispanic or Latino             Married     70.197198
#
#      study_date_anon procdate_anon  cohort_num  path_severity  total_L_find  \
# 0         2016-09-28           NaT           2            NaN           1.0
# 1         2013-01-19    2013-01-20           2            0.0           1.0
# 2         2013-06-29           NaT           2            NaN           1.0
# 3         2014-02-10           NaT           2            NaN           1.0
# 4         2018-08-05    2018-11-10           2            0.0           3.0
# ...              ...           ...         ...            ...           ...
# 1901      2020-03-14    2020-03-28           2            1.0           2.0
# 1902      2020-03-14    2020-03-28           2            1.0           2.0
# 1903      2017-03-19    2017-03-22           2            1.0           2.0
# 1904      2015-06-21    2015-06-28           1            1.0           0.0
# 1905      2019-06-07    2019-06-14           1            1.0           1.0
#
#       total_R_find first_3_zip latest_diagnosed_date
# 0              1.0       300.0            2016-09-28
# 1              0.0       303.0            2014-02-10
# 2              0.0       303.0            2014-02-10
# 3              0.0       303.0            2014-02-10
# 4              0.0       300.0            2019-09-07
# ...            ...         ...                   ...
# 1901           1.0       303.0            2020-03-14
# 1902           1.0       303.0            2020-03-14
# 1903           0.0       301.0            2017-03-19
# 1904           2.0       303.0            2019-06-07
# 1905           1.0         303            2019-06-07
#
# [1906 rows x 22 columns]
# Index(['Unnamed: 0', 'empi_anon', 'acc_anon', 'desc', 'numfind', 'side',
#        'asses', 'tissueden', 'bside', 'GENDER_DESC', 'RACE_DESC',
#        'ETHNIC_GROUP_DESC', 'MARITAL_STATUS_DESC', 'age_at_study',
#        'study_date_anon', 'procdate_anon', 'cohort_num', 'path_severity',
#        'total_L_find', 'total_R_find', 'first_3_zip', 'latest_diagnosed_date'],
#       dtype='object')

# %%
# Ensure that the dates are in datetime format
cancer_df = cancer_df.copy()
screenings_df = df_metadata.copy()
cancer_df.rename(columns={'study_date_anon': 'diagnosed_date_anon'}, inplace=True)

cancer_df['diagnosed_date_anon'] = pd.to_datetime(cancer_df['diagnosed_date_anon'])
screenings_df['study_date_anon'] = pd.to_datetime(screenings_df['study_date_anon'])
cancer_df['latest_diagnosed_date'] = pd.to_datetime(cancer_df['latest_diagnosed_date'])

# Initialize an empty list to store the filtered screenings
filtered_screenings_list = []

# Group cancer images by patient ID and laterality
for _, cancer_row in cancer_df.iterrows():
    patient_id = cancer_row['empi_anon']
    laterality = cancer_row['side']
    cancer_diag_date = cancer_row['diagnosed_date_anon']
    latest_cancer_diag_date = cancer_row['latest_diagnosed_date']

    # Filter screenings for the same patient and laterality, with earlier dates than cancer diagnosis
    patient_screenings = screenings_df[
        (screenings_df['empi_anon'] == patient_id) &  # Match the patient
        (screenings_df['ImageLateralityFinal'] == laterality) &  # Match the laterality
        (screenings_df['study_date_anon'] <= latest_cancer_diag_date)  # Study date should be earlier than cancer diagnosis
    ]

   # Add the cancer diagnosis date to the filtered screenings
    if not patient_screenings.empty:
        patient_screenings = patient_screenings.copy()  # Make a copy to avoid SettingWithCopyWarning
        patient_screenings['diagnosed_date_anon'] = latest_cancer_diag_date

        # Append the updated screenings to the list
        filtered_screenings_list.append(patient_screenings)

# Concatenate all the results into a final DataFrame
final_filtered_screenings = pd.concat(filtered_screenings_list, ignore_index=True)

# Reset index and display the filtered DataFrame
final_filtered_screenings = final_filtered_screenings.reset_index(drop=True)

# Optionally, you can add a label for cancer images in the final result
final_filtered_screenings['Label'] = 'Non-Cancer'
cancer_df['Label'] = 'Cancer'

# Concatenate the cancer images with the filtered screenings
final_combined_df = pd.concat([cancer_df, final_filtered_screenings], ignore_index=True)

# Reset index for clarity
#final_combined_df = final_combined_df.reset_index(drop=True)
# Update the Label to 'Cancer' if diagnosed_date_anon equals study_date_anon
final_combined_df.loc[
    final_combined_df['diagnosed_date_anon'] == final_combined_df['study_date_anon'],
    'Label'
] = 'Cancer'

# Identify patients with multiple exams
patients_with_multiple_exams = final_combined_df.groupby('empi_anon')['acc_anon'].nunique()

# Keep only patients with more than one previous examination
patients_with_multiple_exams = patients_with_multiple_exams[patients_with_multiple_exams > 1].index

# Filter the DataFrame for these patients
filtered_images = final_combined_df[final_combined_df['empi_anon'].isin(patients_with_multiple_exams)]
included_positions = ['CC', 'MLO']
filtered_images = filtered_images[filtered_images['ViewPosition'].isin(included_positions)]
# Reset the index for consistency
filtered_images = filtered_images.reset_index(drop=True)


# Reset index if needed
filtered_images = filtered_images.drop_duplicates(subset=['anon_dicom_path'], keep='first')

get_stats(filtered_images)
display(filtered_images)
# Out:
# DF shape: (5582, 48)
# # Patients: 470
# # Exams: 1717
# # Images dicom: 5582
#        Unnamed: 0  empi_anon          acc_anon desc  numfind side asses  \
# 0          468545   10119504  5579010047669510  NaN      NaN  NaN   NaN
# 1          468554   10119504  5579010047669510  NaN      NaN  NaN   NaN
# 2          468580   10119504  5579010047669510  NaN      NaN  NaN   NaN
# 3          468584   10119504  5579010047669510  NaN      NaN  NaN   NaN
# 4          468465   10119504  9436120411494617  NaN      NaN  NaN   NaN
# ...           ...        ...               ...  ...      ...  ...   ...
# 17124      182804   99868531  8969515521433877  NaN      NaN  NaN   NaN
# 17125      182809   99868531  8969515521433877  NaN      NaN  NaN   NaN
# 17126      182813   99868531  8969515521433877  NaN      NaN  NaN   NaN
# 17127      182823   99868531  8969515521433877  NaN      NaN  NaN   NaN
# 17128      182807   99868531  2145477352100012  NaN      NaN  NaN   NaN
#
#        tissueden bside GENDER_DESC RACE_DESC ETHNIC_GROUP_DESC  \
# 0            NaN   NaN         NaN       NaN               NaN
# 1            NaN   NaN         NaN       NaN               NaN
# 2            NaN   NaN         NaN       NaN               NaN
# 3            NaN   NaN         NaN       NaN               NaN
# 4            NaN   NaN         NaN       NaN               NaN
# ...          ...   ...         ...       ...               ...
# 17124        NaN   NaN         NaN       NaN               NaN
# 17125        NaN   NaN         NaN       NaN               NaN
# 17126        NaN   NaN         NaN       NaN               NaN
# 17127        NaN   NaN         NaN       NaN               NaN
# 17128        NaN   NaN         NaN       NaN               NaN
#
#       MARITAL_STATUS_DESC  age_at_study diagnosed_date_anon procdate_anon  \
# 0                     NaN           NaN          2014-02-10           NaT
# 1                     NaN           NaN          2014-02-10           NaT
# 2                     NaN           NaN          2014-02-10           NaT
# 3                     NaN           NaN          2014-02-10           NaT
# 4                     NaN           NaN          2014-02-10           NaT
# ...                   ...           ...                 ...           ...
# 17124                 NaN           NaN          2019-06-07           NaT
# 17125                 NaN           NaN          2019-06-07           NaT
# 17126                 NaN           NaN          2019-06-07           NaT
# 17127                 NaN           NaN          2019-06-07           NaT
# 17128                 NaN           NaN          2019-06-07           NaT
#
#        cohort_num  path_severity  total_L_find  total_R_find first_3_zip  \
# 0               2            NaN           NaN           NaN         NaN
# 1               2            NaN           NaN           NaN         NaN
# 2               2            NaN           NaN           NaN         NaN
# 3               2            NaN           NaN           NaN         NaN
# 4               2            NaN           NaN           NaN         NaN
# ...           ...            ...           ...           ...         ...
# 17124           1            NaN           NaN           NaN         NaN
# 17125           1            NaN           NaN           NaN         NaN
# 17126           1            NaN           NaN           NaN         NaN
# 17127           1            NaN           NaN           NaN         NaN
# 17128           1            NaN           NaN           NaN         NaN
#
#       latest_diagnosed_date       Label study_date_anon  \
# 0                       NaT  Non-Cancer      2013-01-19
# 1                       NaT  Non-Cancer      2013-01-19
# 2                       NaT  Non-Cancer      2013-01-19
# 3                       NaT  Non-Cancer      2013-01-19
# 4                       NaT  Non-Cancer      2013-06-29
# ...                     ...         ...             ...
# 17124                   NaT  Non-Cancer      2019-04-01
# 17125                   NaT  Non-Cancer      2019-04-01
# 17126                   NaT  Non-Cancer      2019-04-01
# 17127                   NaT  Non-Cancer      2019-04-01
# 17128                   NaT      Cancer      2019-06-07
#
#                                StudyDescription SeriesDescription  \
# 0                 MG Diagnostic Mammo Bilateral              L CC
# 1                 MG Diagnostic Mammo Bilateral             L MLO
# 2                 MG Diagnostic Mammo Bilateral              L CC
# 3                 MG Diagnostic Mammo Bilateral             L MLO
# 4                            MG Diagnostic Left              L CC
# ...                                         ...               ...
# 17124  MG Screen Bilat w/Tomo/CAD Stnd Protocol              R CC
# 17125  MG Screen Bilat w/Tomo/CAD Stnd Protocol      R MLO C-View
# 17126  MG Screen Bilat w/Tomo/CAD Stnd Protocol             R MLO
# 17127  MG Screen Bilat w/Tomo/CAD Stnd Protocol       R CC C-View
# 17128            MG Diagnostic Bilateral w/ CAD              R CC
#
#       FinalImageType ImageLateralityFinal ViewPosition  spot_mag  \
# 0                 2D                    L           CC       NaN
# 1                 2D                    L          MLO       NaN
# 2                 2D                    L           CC       1.0
# 3                 2D                    L          MLO       NaN
# 4                 2D                    L           CC       NaN
# ...              ...                  ...          ...       ...
# 17124             2D                    R           CC       NaN
# 17125          cview                    R          MLO       NaN
# 17126             2D                    R          MLO       NaN
# 17127          cview                    R           CC       NaN
# 17128             2D                    R           CC       1.0
#
#                                          anon_dicom_path  num_roi  \
# 0      /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 1      /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 2      /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 3      /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 4      /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# ...                                                  ...      ...
# 17124  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      1.0
# 17125  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      1.0
# 17126  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      1.0
# 17127  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      1.0
# 17128  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      0.0
#
#                       ROI_coords  \
# 0                             ()
# 1                             ()
# 2                             ()
# 3                             ()
# 4                             ()
# ...                          ...
# 17124  ((2505, 142, 2869, 585),)
# 17125  ((1272, 119, 1446, 434),)
# 17126  ((2120, 198, 2410, 724),)
# 17127   ((1503, 85, 1721, 351),)
# 17128                         ()
#
#                                                  SRC_DST match_level  \
# 0                                                     []          []
# 1                                                     []          []
# 2                                                     []          []
# 3                                                     []          []
# 4                                                     []          []
# ...                                                  ...         ...
# 17124  ['/data/mammo/png_kheiron/kheiron_code/cohort_...         [1]
# 17125  ['/data/mammo/png_kheiron/kheiron_code/cohort_...         [2]
# 17126  ['/data/mammo/png_kheiron/kheiron_code/cohort_...         [1]
# 17127  ['/data/mammo/png_kheiron/kheiron_code/cohort_...         [2]
# 17128                                                 []          []
#
#         Manufacturer ManufacturerModelName PatientSex   ProtocolName  \
# 0      HOLOGIC, Inc.    Selenia Dimensions          F            LCC
# 1      HOLOGIC, Inc.    Selenia Dimensions          F           LMLO
# 2      HOLOGIC, Inc.    Selenia Dimensions          F           LMCC
# 3      HOLOGIC, Inc.    Selenia Dimensions          F           LMLO
# 4      HOLOGIC, Inc.    Selenia Dimensions          F            LCC
# ...              ...                   ...        ...            ...
# 17124  HOLOGIC, Inc.    Selenia Dimensions          F   R CC ComboHD
# 17125  HOLOGIC, Inc.    Selenia Dimensions          F  R MLO ComboHD
# 17126  HOLOGIC, Inc.    Selenia Dimensions          F  R MLO ComboHD
# 17127  HOLOGIC, Inc.    Selenia Dimensions          F   R CC ComboHD
# 17128  HOLOGIC, Inc.    Selenia Dimensions          F          R MCC
#
#        SeriesNumber  SeriesTime           StudyID WindowCenter WindowWidth  \
# 0        71100000.0     85949.0  MG Diagnostic Ma       2047.0      4096.0
# 1        71100000.0     90443.0  MG Diagnostic Ma       2047.0      4096.0
# 2        71100000.0     91253.0  MG Diagnostic Ma       2047.0      4096.0
# 3        71100000.0     90312.0  MG Diagnostic Ma       2047.0      4096.0
# 4        71100000.0    141139.0  MG Diagnostic Ma       2047.0      4096.0
# ...             ...         ...               ...          ...         ...
# 17124    71300000.0     90627.0   MG Screen Bilat       2047.0      4096.0
# 17125    71300000.0     91049.0   MG Screen Bilat        540.0       580.0
# 17126    71300000.0     91049.0   MG Screen Bilat       2047.0      4096.0
# 17127    71300000.0     90627.0   MG Screen Bilat        540.0       580.0
# 17128    71100000.0    104421.0  MG Diagnostic Bi       2047.0      4096.0
#
#       has_pix_array  category VOILUTFunction WindowCenterWidthExplanation
# 0             False  no image            NaN                          NaN
# 1             False  no image            NaN                          NaN
# 2             False  no image            NaN                          NaN
# 3             False  no image            NaN                          NaN
# 4             False  no image            NaN                          NaN
# ...             ...       ...            ...                          ...
# 17124         False  no image            NaN                          NaN
# 17125         False  no image            NaN                          NaN
# 17126         False  no image            NaN                          NaN
# 17127         False  no image            NaN                          NaN
# 17128         False  no image            NaN                          NaN
#
# [5582 rows x 48 columns]

# %%
filtered_images_final = filtered_images.copy()
filtered_images_final = filtered_images_final[~filtered_images_final['ProtocolName'].str.contains('SCC|SMLO|CCRL|CCID|MLOID|MLOIMF|MCC|MLOAC|CCAC|MLOIDIMF|MLONP|CCNP|MLOAX|MLOAXIMF|TAN|CCRM|CCAX|CEDM|CESM', case=False, na=False)]

filtered_images_final = filtered_images_final.drop(['latest_diagnosed_date','cohort_num','Unnamed: 0','PatientSex','MARITAL_STATUS_DESC','RACE_DESC','GENDER_DESC','desc' , 'first_3_zip', 'SRC_DST','spot_mag', 'ManufacturerModelName' , 'SeriesNumber', 'SeriesTime','match_level' ,'ETHNIC_GROUP_DESC', 'age_at_study'], axis=1)
filtered_images_final.to_csv("/content/POSITIVE_GROUP_with_screenings_NEW_2D_CView.csv", index=False)

display(filtered_images_final)
get_stats(filtered_images_final)
# Out:
#        empi_anon          acc_anon  numfind side asses  tissueden bside  \
# 0       10119504  5579010047669510      NaN  NaN   NaN        NaN   NaN
# 1       10119504  5579010047669510      NaN  NaN   NaN        NaN   NaN
# 3       10119504  5579010047669510      NaN  NaN   NaN        NaN   NaN
# 4       10119504  9436120411494617      NaN  NaN   NaN        NaN   NaN
# 5       10119504  9436120411494617      NaN  NaN   NaN        NaN   NaN
# ...          ...               ...      ...  ...   ...        ...   ...
# 17123   99868531  6018116494364687      NaN  NaN   NaN        NaN   NaN
# 17124   99868531  8969515521433877      NaN  NaN   NaN        NaN   NaN
# 17125   99868531  8969515521433877      NaN  NaN   NaN        NaN   NaN
# 17126   99868531  8969515521433877      NaN  NaN   NaN        NaN   NaN
# 17127   99868531  8969515521433877      NaN  NaN   NaN        NaN   NaN
#
#       diagnosed_date_anon procdate_anon  path_severity  total_L_find  \
# 0              2014-02-10           NaT            NaN           NaN
# 1              2014-02-10           NaT            NaN           NaN
# 3              2014-02-10           NaT            NaN           NaN
# 4              2014-02-10           NaT            NaN           NaN
# 5              2014-02-10           NaT            NaN           NaN
# ...                   ...           ...            ...           ...
# 17123          2019-06-07           NaT            NaN           NaN
# 17124          2019-06-07           NaT            NaN           NaN
# 17125          2019-06-07           NaT            NaN           NaN
# 17126          2019-06-07           NaT            NaN           NaN
# 17127          2019-06-07           NaT            NaN           NaN
#
#        total_R_find       Label study_date_anon  \
# 0               NaN  Non-Cancer      2013-01-19
# 1               NaN  Non-Cancer      2013-01-19
# 3               NaN  Non-Cancer      2013-01-19
# 4               NaN  Non-Cancer      2013-06-29
# 5               NaN  Non-Cancer      2013-06-29
# ...             ...         ...             ...
# 17123           NaN  Non-Cancer      2018-03-19
# 17124           NaN  Non-Cancer      2019-04-01
# 17125           NaN  Non-Cancer      2019-04-01
# 17126           NaN  Non-Cancer      2019-04-01
# 17127           NaN  Non-Cancer      2019-04-01
#
#                                StudyDescription SeriesDescription  \
# 0                 MG Diagnostic Mammo Bilateral              L CC
# 1                 MG Diagnostic Mammo Bilateral             L MLO
# 3                 MG Diagnostic Mammo Bilateral             L MLO
# 4                            MG Diagnostic Left              L CC
# 5                            MG Diagnostic Left             L MLO
# ...                                         ...               ...
# 17123            MG Diagnostic Bilateral w/ CAD             R MLO
# 17124  MG Screen Bilat w/Tomo/CAD Stnd Protocol              R CC
# 17125  MG Screen Bilat w/Tomo/CAD Stnd Protocol      R MLO C-View
# 17126  MG Screen Bilat w/Tomo/CAD Stnd Protocol             R MLO
# 17127  MG Screen Bilat w/Tomo/CAD Stnd Protocol       R CC C-View
#
#       FinalImageType ImageLateralityFinal ViewPosition  \
# 0                 2D                    L           CC
# 1                 2D                    L          MLO
# 3                 2D                    L          MLO
# 4                 2D                    L           CC
# 5                 2D                    L          MLO
# ...              ...                  ...          ...
# 17123             2D                    R          MLO
# 17124             2D                    R           CC
# 17125          cview                    R          MLO
# 17126             2D                    R          MLO
# 17127          cview                    R           CC
#
#                                          anon_dicom_path  num_roi  \
# 0      /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 1      /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 3      /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 4      /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 5      /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# ...                                                  ...      ...
# 17123  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      0.0
# 17124  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      1.0
# 17125  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      1.0
# 17126  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      1.0
# 17127  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      1.0
#
#                       ROI_coords   Manufacturer   ProtocolName  \
# 0                             ()  HOLOGIC, Inc.            LCC
# 1                             ()  HOLOGIC, Inc.           LMLO
# 3                             ()  HOLOGIC, Inc.           LMLO
# 4                             ()  HOLOGIC, Inc.            LCC
# 5                             ()  HOLOGIC, Inc.           LMLO
# ...                          ...            ...            ...
# 17123                         ()  HOLOGIC, Inc.          R MLO
# 17124  ((2505, 142, 2869, 585),)  HOLOGIC, Inc.   R CC ComboHD
# 17125  ((1272, 119, 1446, 434),)  HOLOGIC, Inc.  R MLO ComboHD
# 17126  ((2120, 198, 2410, 724),)  HOLOGIC, Inc.  R MLO ComboHD
# 17127   ((1503, 85, 1721, 351),)  HOLOGIC, Inc.   R CC ComboHD
#
#                 StudyID WindowCenter WindowWidth has_pix_array  category  \
# 0      MG Diagnostic Ma       2047.0      4096.0         False  no image
# 1      MG Diagnostic Ma       2047.0      4096.0         False  no image
# 3      MG Diagnostic Ma       2047.0      4096.0         False  no image
# 4      MG Diagnostic Ma       2047.0      4096.0         False  no image
# 5      MG Diagnostic Ma       2047.0      4096.0         False  no image
# ...                 ...          ...         ...           ...       ...
# 17123  MG Diagnostic Ma       2047.0      4096.0         False  no image
# 17124   MG Screen Bilat       2047.0      4096.0         False  no image
# 17125   MG Screen Bilat        540.0       580.0         False  no image
# 17126   MG Screen Bilat       2047.0      4096.0         False  no image
# 17127   MG Screen Bilat        540.0       580.0         False  no image
#
#       VOILUTFunction WindowCenterWidthExplanation
# 0                NaN                          NaN
# 1                NaN                          NaN
# 3                NaN                          NaN
# 4                NaN                          NaN
# 5                NaN                          NaN
# ...              ...                          ...
# 17123            NaN                          NaN
# 17124            NaN                          NaN
# 17125            NaN                          NaN
# 17126            NaN                          NaN
# 17127            NaN                          NaN
#
# [4279 rows x 31 columns]
# DF shape: (4279, 31)
# # Patients: 470
# # Exams: 1456
# # Images dicom: 4279

# %% [markdown]
# #   Calculate Time to Cancer for Each Image with a cancer diagnosis (calcualte it betweeen the cancer image and each corresponding previous image)

# %%
# Step 1: Ensure the dataframe is sorted for each patient

df_final_img_time_cancer = filtered_images_final.copy()
df_final_img_time_cancer = df_final_img_time_cancer.sort_values(by=['empi_anon'])
# Ensure both dates are in datetime format
df_final_img_time_cancer['diagnosed_date_anon'] = pd.to_datetime(df_final_img_time_cancer['diagnosed_date_anon'])
df_final_img_time_cancer['study_date_anon'] = pd.to_datetime(df_final_img_time_cancer['study_date_anon'])


# Extract the year components
df_final_img_time_cancer['diagnosed_date_anon_year'] = df_final_img_time_cancer['diagnosed_date_anon'].dt.year
df_final_img_time_cancer['study_date_year'] = df_final_img_time_cancer['study_date_anon'].dt.year

# Calculate Time to Cancer in years (difference between years only)
df_final_img_time_cancer['Time_to_Cancer_Years'] = (
    df_final_img_time_cancer['diagnosed_date_anon_year'] - df_final_img_time_cancer['study_date_year'])
df_final_img_time_cancer = df_final_img_time_cancer[df_final_img_time_cancer['Time_to_Cancer_Years'] <= 5]
df_final_img_time_cancer = df_final_img_time_cancer[df_final_img_time_cancer['Time_to_Cancer_Years'] >= 0]

df_final_img_time_cancer = df_final_img_time_cancer[df_final_img_time_cancer.FinalImageType == '2D'].reset_index(drop=True)

# remove patients with only one examination
patients_with_multiple_exams = df_final_img_time_cancer.groupby('empi_anon')['acc_anon'].nunique()

# Filter out patients with only one examination
patients_with_multiple_exams = patients_with_multiple_exams[patients_with_multiple_exams > 1]

# Now, filter the original dataframe to include only patients with multiple examinations
df_final_img_time_cancer = df_final_img_time_cancer[df_final_img_time_cancer['empi_anon'].isin(patients_with_multiple_exams.index)]


# Step 2: Define groups based on time-to-cancer
def assign_group(row):
    if row['Label'] == 'Cancer':
        return None  # Exclude cancer patients
    time = row['Time_to_Cancer_Years']
    if 0 <= time <= 1:
        return 'BC 1Y'
    elif 1 < time <= 2:
        return 'BC 2Y'
    elif 2 < time <= 3:
        return 'BC 3Y'
    elif 3 < time <= 4:
        return 'BC 4Y'
    elif 4 < time <= 5:
        return 'BC 5Y'


# Apply the function
df_final_img_time_cancer['time_to_cancer_group'] = df_final_img_time_cancer.apply(assign_group, axis=1)

# Step 3: Summarize distribution
distribution = df_final_img_time_cancer.groupby('time_to_cancer_group').size().reset_index(name='count')
df_final_img_time_cancer = df_final_img_time_cancer.sort_values(by=['empi_anon', 'acc_anon', 'ImageLateralityFinal']).reset_index(drop=True)

df_final_img_time_cancer.to_csv("/content/POSITIVE_GROUP_with_screenings_time_to_cancer_NEW.csv", index=False)

# Display results
print(distribution)

get_stats(df_final_img_time_cancer)
display(df_final_img_time_cancer)
# Out:
#   time_to_cancer_group  count
# 0                BC 1Y   1276
# 1                BC 2Y    468
# 2                BC 3Y    374
# 3                BC 4Y    224
# 4                BC 5Y    164
# DF shape: (3090, 35)
# # Patients: 377
# # Exams: 1301
# # Images dicom: 3090
#       empi_anon          acc_anon  numfind side asses  tissueden bside  \
# 0      10119504  5579010047669510      NaN  NaN   NaN        NaN   NaN
# 1      10119504  5579010047669510      NaN  NaN   NaN        NaN   NaN
# 2      10119504  5579010047669510      NaN  NaN   NaN        NaN   NaN
# 3      10119504  9436120411494617      NaN  NaN   NaN        NaN   NaN
# 4      10119504  9436120411494617      NaN  NaN   NaN        NaN   NaN
# ...         ...               ...      ...  ...   ...        ...   ...
# 3085   99868531  8969515521433877      NaN  NaN   NaN        NaN   NaN
# 3086   99868531  9090933158477514      NaN  NaN   NaN        NaN   NaN
# 3087   99868531  9090933158477514      NaN  NaN   NaN        NaN   NaN
# 3088   99868531  9161828304530939      NaN  NaN   NaN        NaN   NaN
# 3089   99868531  9161828304530939      NaN  NaN   NaN        NaN   NaN
#
#      diagnosed_date_anon procdate_anon  path_severity  total_L_find  \
# 0             2014-02-10           NaT            NaN           NaN
# 1             2014-02-10           NaT            NaN           NaN
# 2             2014-02-10           NaT            NaN           NaN
# 3             2014-02-10           NaT            NaN           NaN
# 4             2014-02-10           NaT            NaN           NaN
# ...                  ...           ...            ...           ...
# 3085          2019-06-07           NaT            NaN           NaN
# 3086          2019-06-07           NaT            NaN           NaN
# 3087          2019-06-07           NaT            NaN           NaN
# 3088          2019-06-07           NaT            NaN           NaN
# 3089          2019-06-07           NaT            NaN           NaN
#
#       total_R_find       Label study_date_anon  \
# 0              NaN  Non-Cancer      2013-01-19
# 1              NaN  Non-Cancer      2013-01-19
# 2              NaN  Non-Cancer      2013-01-19
# 3              NaN  Non-Cancer      2013-06-29
# 4              NaN  Non-Cancer      2013-06-29
# ...            ...         ...             ...
# 3085           NaN  Non-Cancer      2019-04-01
# 3086           NaN  Non-Cancer      2015-06-21
# 3087           NaN  Non-Cancer      2015-06-21
# 3088           NaN  Non-Cancer      2016-02-01
# 3089           NaN  Non-Cancer      2016-02-01
#
#                               StudyDescription SeriesDescription  \
# 0                MG Diagnostic Mammo Bilateral              L CC
# 1                MG Diagnostic Mammo Bilateral             L MLO
# 2                MG Diagnostic Mammo Bilateral             L MLO
# 3                           MG Diagnostic Left              L CC
# 4                           MG Diagnostic Left             L MLO
# ...                                        ...               ...
# 3085  MG Screen Bilat w/Tomo/CAD Stnd Protocol             R MLO
# 3086                 MG Diagnostic Right w/CAD             R MLO
# 3087                 MG Diagnostic Right w/CAD              R CC
# 3088            MG Diagnostic Bilateral w/ CAD              R CC
# 3089            MG Diagnostic Bilateral w/ CAD             R MLO
#
#      FinalImageType ImageLateralityFinal ViewPosition  \
# 0                2D                    L           CC
# 1                2D                    L          MLO
# 2                2D                    L          MLO
# 3                2D                    L           CC
# 4                2D                    L          MLO
# ...             ...                  ...          ...
# 3085             2D                    R          MLO
# 3086             2D                    R          MLO
# 3087             2D                    R           CC
# 3088             2D                    R           CC
# 3089             2D                    R          MLO
#
#                                         anon_dicom_path  num_roi  \
# 0     /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 1     /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 2     /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 3     /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# 4     /mnt/NAS2/mammo/anon_dicom/cohort_2/10119504/1...      0.0
# ...                                                 ...      ...
# 3085  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      1.0
# 3086  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      0.0
# 3087  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      0.0
# 3088  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      0.0
# 3089  /mnt/NAS2/mammo/anon_dicom/cohort_1/99868531/1...      0.0
#
#                      ROI_coords   Manufacturer   ProtocolName  \
# 0                            ()  HOLOGIC, Inc.            LCC
# 1                            ()  HOLOGIC, Inc.           LMLO
# 2                            ()  HOLOGIC, Inc.           LMLO
# 3                            ()  HOLOGIC, Inc.            LCC
# 4                            ()  HOLOGIC, Inc.           LMLO
# ...                         ...            ...            ...
# 3085  ((2120, 198, 2410, 724),)  HOLOGIC, Inc.  R MLO ComboHD
# 3086                         ()  HOLOGIC, Inc.          R MLO
# 3087                         ()  HOLOGIC, Inc.           R CC
# 3088                         ()  HOLOGIC, Inc.           R CC
# 3089                         ()  HOLOGIC, Inc.          R MLO
#
#                StudyID WindowCenter WindowWidth has_pix_array  category  \
# 0     MG Diagnostic Ma       2047.0      4096.0         False  no image
# 1     MG Diagnostic Ma       2047.0      4096.0         False  no image
# 2     MG Diagnostic Ma       2047.0      4096.0         False  no image
# 3     MG Diagnostic Ma       2047.0      4096.0         False  no image
# 4     MG Diagnostic Ma       2047.0      4096.0         False  no image
# ...                ...          ...         ...           ...       ...
# 3085   MG Screen Bilat       2047.0      4096.0         False  no image
# 3086  MG Diagnostic Ma       2047.0      4096.0         False  no image
# 3087  MG Diagnostic Ma       2047.0      4096.0         False  no image
# 3088  MG Diagnostic Ma       2047.0      4096.0         False  no image
# 3089  MG Diagnostic Ma       2047.0      4096.0         False  no image
#
#      VOILUTFunction WindowCenterWidthExplanation  diagnosed_date_anon_year  \
# 0               NaN                          NaN                      2014
# 1               NaN                          NaN                      2014
# 2               NaN                          NaN                      2014
# 3               NaN                          NaN                      2014
# 4               NaN                          NaN                      2014
# ...             ...                          ...                       ...
# 3085            NaN                          NaN                      2019
# 3086            NaN                          NaN                      2019
# 3087            NaN                          NaN                      2019
# 3088            NaN                          NaN                      2019
# 3089            NaN                          NaN                      2019
#
#       study_date_year  Time_to_Cancer_Years time_to_cancer_group
# 0                2013                     1                BC 1Y
# 1                2013                     1                BC 1Y
# 2                2013                     1                BC 1Y
# 3                2013                     1                BC 1Y
# 4                2013                     1                BC 1Y
# ...               ...                   ...                  ...
# 3085             2019                     0                BC 1Y
# 3086             2015                     4                BC 4Y
# 3087             2015                     4                BC 4Y
# 3088             2016                     3                BC 3Y
# 3089             2016                     3                BC 3Y
#
# [3090 rows x 35 columns]

# %% [markdown]
# # Plot the Time-to-Cancer Label Distribution

# %%
# Count the number of images in each bin
image_counts_per_bin = df_final_img_time_cancer['time_to_cancer_group'].value_counts().sort_index()

# Print the counts for each bin
print(image_counts_per_bin)

# Values from the paper (for comparison)
values_paper = [1034, 408, 274, 206, 154]

# Create the figure and axes
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# First plot (Bar plot for Time to Cancer from your dataset)
axes[0].bar(image_counts_per_bin.index.tolist(), image_counts_per_bin.values.tolist(), edgecolor='black')
axes[0].set_xlabel('Time to Cancer (Years to Diagnosis)')
axes[0].set_ylabel('Number of images')
axes[0].tick_params(axis='x', rotation=45)
axes[0].set_title('Distribution of Time to Cancer (My EMBED dataset)')

# Add values above the bars for the first plot
for i, value in enumerate(image_counts_per_bin.values):
    axes[0].text(i, value + 10, str(value), ha='center', va='bottom', fontsize=10)  # Adjust the position as needed

# Second plot (Bar plot for Time to Cancer from 'values_paper')
axes[1].bar(['BC 1Y', 'BC 2Y', 'BC 3Y', 'BC 4Y', 'BC 5Y'], values_paper, edgecolor='black')
axes[1].set_xlabel('Time to Cancer (Years to Diagnosis)')
axes[1].set_ylabel('Number of images')
axes[1].tick_params(axis='x', rotation=45)
axes[1].set_title('Distribution of Time to Cancer (MICCA Paper EMBED dataset)')

# Add values above the bars for the second plot
for i, value in enumerate(values_paper):
    axes[1].text(i, value + 10, str(value), ha='center', va='bottom', fontsize=10)  # Adjust the position as needed

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# time_to_cancer_group
# BC 1Y    1276
# BC 2Y     468
# BC 3Y     374
# BC 4Y     224
# BC 5Y     164
# Name: count, dtype: int64

# %% [markdown]
# # fixing dicom file paths to the local ones.

# %%
def anon_dicom_path_fix(DICOMPathStr):
    return DICOMPathStr.replace('/mnt/NAS2/mammo/anon_dicom', '/storage2/images')
result_df_pos_group = df_final_img_time_cancer.copy()
result_df_pos_group['anon_dicom_path_local']=result_df_pos_group['anon_dicom_path'].apply(anon_dicom_path_fix)
result_df_pos_group_final = result_df_pos_group.rename(columns={'empi_anon': 'patient_id','acc_anon': 'exam_id', 'ImageLateralityFinall': 'laterality' , 'ViewPosition': 'view','anon_dicom_path_local': 'file_path_dcm' })
result_df_pos_group_final = result_df_pos_group_final.drop(columns=["anon_dicom_path",  "StudyID"  ,"numfind"  ,"tissueden", "SeriesDescription" , "asses","path_severity","bside",  "side", "StudyDescription", "FinalImageType"  ])

display(result_df_pos_group_final)

result_df_pos_group_final.to_csv("/content/POSITIVE_GROUP_FINAL_2D_only.csv", index=False)
print(result_df_pos_group_final['patient_id'].nunique())
# Out:
#       patient_id           exam_id diagnosed_date_anon procdate_anon  \
# 0       10119504  5579010047669510          2014-02-10           NaT
# 1       10119504  5579010047669510          2014-02-10           NaT
# 2       10119504  5579010047669510          2014-02-10           NaT
# 3       10119504  9436120411494617          2014-02-10           NaT
# 4       10119504  9436120411494617          2014-02-10           NaT
# ...          ...               ...                 ...           ...
# 3085    99868531  8969515521433877          2019-06-07           NaT
# 3086    99868531  9090933158477514          2019-06-07           NaT
# 3087    99868531  9090933158477514          2019-06-07           NaT
# 3088    99868531  9161828304530939          2019-06-07           NaT
# 3089    99868531  9161828304530939          2019-06-07           NaT
#
#       total_L_find  total_R_find       Label study_date_anon  \
# 0              NaN           NaN  Non-Cancer      2013-01-19
# 1              NaN           NaN  Non-Cancer      2013-01-19
# 2              NaN           NaN  Non-Cancer      2013-01-19
# 3              NaN           NaN  Non-Cancer      2013-06-29
# 4              NaN           NaN  Non-Cancer      2013-06-29
# ...            ...           ...         ...             ...
# 3085           NaN           NaN  Non-Cancer      2019-04-01
# 3086           NaN           NaN  Non-Cancer      2015-06-21
# 3087           NaN           NaN  Non-Cancer      2015-06-21
# 3088           NaN           NaN  Non-Cancer      2016-02-01
# 3089           NaN           NaN  Non-Cancer      2016-02-01
#
#      ImageLateralityFinal view  num_roi                 ROI_coords  \
# 0                       L   CC      0.0                         ()
# 1                       L  MLO      0.0                         ()
# 2                       L  MLO      0.0                         ()
# 3                       L   CC      0.0                         ()
# 4                       L  MLO      0.0                         ()
# ...                   ...  ...      ...                        ...
# 3085                    R  MLO      1.0  ((2120, 198, 2410, 724),)
# 3086                    R  MLO      0.0                         ()
# 3087                    R   CC      0.0                         ()
# 3088                    R   CC      0.0                         ()
# 3089                    R  MLO      0.0                         ()
#
#        Manufacturer   ProtocolName WindowCenter WindowWidth has_pix_array  \
# 0     HOLOGIC, Inc.            LCC       2047.0      4096.0         False
# 1     HOLOGIC, Inc.           LMLO       2047.0      4096.0         False
# 2     HOLOGIC, Inc.           LMLO       2047.0      4096.0         False
# 3     HOLOGIC, Inc.            LCC       2047.0      4096.0         False
# 4     HOLOGIC, Inc.           LMLO       2047.0      4096.0         False
# ...             ...            ...          ...         ...           ...
# 3085  HOLOGIC, Inc.  R MLO ComboHD       2047.0      4096.0         False
# 3086  HOLOGIC, Inc.          R MLO       2047.0      4096.0         False
# 3087  HOLOGIC, Inc.           R CC       2047.0      4096.0         False
# 3088  HOLOGIC, Inc.           R CC       2047.0      4096.0         False
# 3089  HOLOGIC, Inc.          R MLO       2047.0      4096.0         False
#
#       category VOILUTFunction WindowCenterWidthExplanation  \
# 0     no image            NaN                          NaN
# 1     no image            NaN                          NaN
# 2     no image            NaN                          NaN
# 3     no image            NaN                          NaN
# 4     no image            NaN                          NaN
# ...        ...            ...                          ...
# 3085  no image            NaN                          NaN
# 3086  no image            NaN                          NaN
# 3087  no image            NaN                          NaN
# 3088  no image            NaN                          NaN
# 3089  no image            NaN                          NaN
#
#       diagnosed_date_anon_year  study_date_year  Time_to_Cancer_Years  \
# 0                         2014             2013                     1
# 1                         2014             2013                     1
# 2                         2014             2013                     1
# 3                         2014             2013                     1
# 4                         2014             2013                     1
# ...                        ...              ...                   ...
# 3085                      2019             2019                     0
# 3086                      2019             2015                     4
# 3087                      2019             2015                     4
# 3088                      2019             2016                     3
# 3089                      2019             2016                     3
#
#      time_to_cancer_group                                      file_path_dcm
# 0                   BC 1Y  /storage2/images/cohort_2/10119504/1.2.846.113...
# 1                   BC 1Y  /storage2/images/cohort_2/10119504/1.2.846.113...
# 2                   BC 1Y  /storage2/images/cohort_2/10119504/1.2.846.113...
# 3                   BC 1Y  /storage2/images/cohort_2/10119504/1.2.847.113...
# 4                   BC 1Y  /storage2/images/cohort_2/10119504/1.2.847.113...
# ...                   ...                                                ...
# 3085                BC 1Y  /storage2/images/cohort_1/99868531/1.2.849.113...
# 3086                BC 4Y  /storage2/images/cohort_1/99868531/1.2.840.113...
# 3087                BC 4Y  /storage2/images/cohort_1/99868531/1.2.840.113...
# 3088                BC 3Y  /storage2/images/cohort_1/99868531/1.2.846.113...
# 3089                BC 3Y  /storage2/images/cohort_1/99868531/1.2.846.113...
#
# [3090 rows x 25 columns]
# 377
