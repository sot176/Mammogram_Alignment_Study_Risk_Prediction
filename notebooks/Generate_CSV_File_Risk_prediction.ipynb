# %%
import pandas as pd
from datetime import datetime

# %%
# Load CSV files
positive_cases = pd.read_csv('POSITIVE_GROUP_FINAL.csv', parse_dates=['study_date_anon', 'diagnosed_date_anon'])
negative_cases = pd.read_csv('NEGATIVE_GROUP_FINAL.csv', parse_dates=['study_date_anon'])

# %%
negative_cases.rename(columns={'empi_anon': 'patient_id', 'acc_anon': 'exam_id', 'ViewPosition':'view'}, inplace=True)

# %%
display(positive_cases)
# Out:
#       patient_id           exam_id diagnosed_date_anon  procdate_anon  \
# 0       10119504  5579010047669510          2014-02-10            NaN
# 1       10119504  5579010047669510          2014-02-10            NaN
# 2       10119504  5579010047669510          2014-02-10            NaN
# 3       10119504  9436120411494617          2014-02-10            NaN
# 4       10119504  9436120411494617          2014-02-10            NaN
# ...          ...               ...                 ...            ...
# 3085    99868531  8969515521433877          2019-06-07            NaN
# 3086    99868531  9090933158477514          2019-06-07            NaN
# 3087    99868531  9090933158477514          2019-06-07            NaN
# 3088    99868531  9161828304530939          2019-06-07            NaN
# 3089    99868531  9161828304530939          2019-06-07            NaN
#
#       total_L_find  total_R_find       Label study_date_anon  \
# 0              NaN           NaN  Non-Cancer      2013-01-19
# 1              NaN           NaN  Non-Cancer      2013-01-19
# 2              NaN           NaN  Non-Cancer      2013-01-19
# 3              NaN           NaN  Non-Cancer      2013-06-29
# 4              NaN           NaN  Non-Cancer      2013-06-29
# ...            ...           ...         ...             ...
# 3085           NaN           NaN  Non-Cancer      2019-04-01
# 3086           NaN           NaN  Non-Cancer      2015-06-21
# 3087           NaN           NaN  Non-Cancer      2015-06-21
# 3088           NaN           NaN  Non-Cancer      2016-02-01
# 3089           NaN           NaN  Non-Cancer      2016-02-01
#
#      ImageLateralityFinal view  ...  WindowWidth has_pix_array  category  \
# 0                       L   CC  ...       4096.0         False  no image
# 1                       L  MLO  ...       4096.0         False  no image
# 2                       L  MLO  ...       4096.0         False  no image
# 3                       L   CC  ...       4096.0         False  no image
# 4                       L  MLO  ...       4096.0         False  no image
# ...                   ...  ...  ...          ...           ...       ...
# 3085                    R  MLO  ...       4096.0         False  no image
# 3086                    R  MLO  ...       4096.0         False  no image
# 3087                    R   CC  ...       4096.0         False  no image
# 3088                    R   CC  ...       4096.0         False  no image
# 3089                    R  MLO  ...       4096.0         False  no image
#
#      VOILUTFunction WindowCenterWidthExplanation diagnosed_date_anon_year  \
# 0               NaN                          NaN                     2014
# 1               NaN                          NaN                     2014
# 2               NaN                          NaN                     2014
# 3               NaN                          NaN                     2014
# 4               NaN                          NaN                     2014
# ...             ...                          ...                      ...
# 3085            NaN                          NaN                     2019
# 3086            NaN                          NaN                     2019
# 3087            NaN                          NaN                     2019
# 3088            NaN                          NaN                     2019
# 3089            NaN                          NaN                     2019
#
#       study_date_year Time_to_Cancer_Years time_to_cancer_group  \
# 0                2013                    1                BC 1Y
# 1                2013                    1                BC 1Y
# 2                2013                    1                BC 1Y
# 3                2013                    1                BC 1Y
# 4                2013                    1                BC 1Y
# ...               ...                  ...                  ...
# 3085             2019                    0                BC 1Y
# 3086             2015                    4                BC 4Y
# 3087             2015                    4                BC 4Y
# 3088             2016                    3                BC 3Y
# 3089             2016                    3                BC 3Y
#
#                                           file_path_dcm
# 0     /storage2/images/cohort_2/10119504/1.2.846.113...
# 1     /storage2/images/cohort_2/10119504/1.2.846.113...
# 2     /storage2/images/cohort_2/10119504/1.2.846.113...
# 3     /storage2/images/cohort_2/10119504/1.2.847.113...
# 4     /storage2/images/cohort_2/10119504/1.2.847.113...
# ...                                                 ...
# 3085  /storage2/images/cohort_1/99868531/1.2.849.113...
# 3086  /storage2/images/cohort_1/99868531/1.2.840.113...
# 3087  /storage2/images/cohort_1/99868531/1.2.840.113...
# 3088  /storage2/images/cohort_1/99868531/1.2.846.113...
# 3089  /storage2/images/cohort_1/99868531/1.2.846.113...
#
# [3090 rows x 25 columns]

# %%
display(negative_cases)
# Out:
#        patient_id           exam_id  \
# 0        10093833  2030506250163251
# 1        10093833  2030506250163251
# 2        10093833  2030506250163251
# 3        10093833  2030506250163251
# 4        10093833  2500827897014911
# ...           ...               ...
# 49350    99986224  8107409307566891
# 49351    99986224  9061973132112039
# 49352    99986224  9061973132112039
# 49353    99986224  9061973132112039
# 49354    99986224  9061973132112039
#
#                                          anon_dicom_path  \
# 0      /storage2/images/cohort_2/10093833/1.2.846.113...
# 1      /storage2/images/cohort_2/10093833/1.2.846.113...
# 2      /storage2/images/cohort_2/10093833/1.2.846.113...
# 3      /storage2/images/cohort_2/10093833/1.2.846.113...
# 4      /storage2/images/cohort_2/10093833/1.2.842.113...
# ...                                                  ...
# 49350  /storage2/images/cohort_1/99986224/1.2.843.113...
# 49351  /storage2/images/cohort_1/99986224/1.2.843.113...
# 49352  /storage2/images/cohort_1/99986224/1.2.843.113...
# 49353  /storage2/images/cohort_1/99986224/1.2.843.113...
# 49354  /storage2/images/cohort_1/99986224/1.2.843.113...
#
#                                            desc   ProtocolName asses  \
# 0                  MG Screening Bilateral w/CAD           L CC     N
# 1                  MG Screening Bilateral w/CAD           R CC     N
# 2                  MG Screening Bilateral w/CAD          L MLO     N
# 3                  MG Screening Bilateral w/CAD          R MLO     N
# 4                  MG Screening Bilateral w/CAD           L CC     N
# ...                                         ...            ...   ...
# 49350  MG Screen Bilat w/Tomo/CAD Stnd Protocol  R MLO ComboHD     N
# 49351              MG Screening Bilateral w/CAD           L CC     N
# 49352              MG Screening Bilateral w/CAD           R CC     N
# 49353              MG Screening Bilateral w/CAD          L MLO     N
# 49354              MG Screening Bilateral w/CAD          R MLO     N
#
#        path_severity study_date_anon side ImageLateralityFinal bside view  \
# 0                NaN      2013-06-21    L                    L   NaN   CC
# 1                NaN      2013-06-21    R                    R   NaN   CC
# 2                NaN      2013-06-21    L                    L   NaN  MLO
# 3                NaN      2013-06-21    R                    R   NaN  MLO
# 4                NaN      2014-07-02    L                    L   NaN   CC
# ...              ...             ...  ...                  ...   ...  ...
# 49350            NaN      2018-05-22    R                    R   NaN  MLO
# 49351            NaN      2013-04-10    L                    L   NaN   CC
# 49352            NaN      2013-04-10    R                    R   NaN   CC
# 49353            NaN      2013-04-10    L                    L   NaN  MLO
# 49354            NaN      2013-04-10    R                    R   NaN  MLO
#
#       match_level  num_roi ROI_coords
# 0              []        0         ()
# 1              []        0         ()
# 2              []        0         ()
# 3              []        0         ()
# 4              []        0         ()
# ...           ...      ...        ...
# 49350          []        0         ()
# 49351          []        0         ()
# 49352          []        0         ()
# 49353          []        0         ()
# 49354          []        0         ()
#
# [49355 rows x 15 columns]

# %%
# For positive cases
def calculate_positive_followup(row):
    # Compute difference in years between the exam date and cancer diagnosis date
    return (row['diagnosed_date_anon'] - row['study_date_anon']).days / 365.25

positive_cases['years_last_followup'] = positive_cases.apply(calculate_positive_followup, axis=1)
positive_cases['years_last_followup'] = positive_cases['years_last_followup'].astype(int)
# For negative cases
def calculate_negative_followup(patient_df):
    # Determine the latest exam date for each patient
    latest_date = patient_df['study_date_anon'].max()
    # Compute difference in years between the exam date and the latest available date
    patient_df['years_last_followup'] = (latest_date - patient_df['study_date_anon']).dt.days / 365.25
    patient_df['years_last_followup'] = patient_df['years_last_followup'].astype(int)
    return patient_df

# %%
display(positive_cases)
# Out:
#       patient_id           exam_id diagnosed_date_anon  procdate_anon  \
# 0       10119504  5579010047669510          2014-02-10            NaN
# 1       10119504  5579010047669510          2014-02-10            NaN
# 2       10119504  5579010047669510          2014-02-10            NaN
# 3       10119504  9436120411494617          2014-02-10            NaN
# 4       10119504  9436120411494617          2014-02-10            NaN
# ...          ...               ...                 ...            ...
# 3085    99868531  8969515521433877          2019-06-07            NaN
# 3086    99868531  9090933158477514          2019-06-07            NaN
# 3087    99868531  9090933158477514          2019-06-07            NaN
# 3088    99868531  9161828304530939          2019-06-07            NaN
# 3089    99868531  9161828304530939          2019-06-07            NaN
#
#       total_L_find  total_R_find       Label study_date_anon  \
# 0              NaN           NaN  Non-Cancer      2013-01-19
# 1              NaN           NaN  Non-Cancer      2013-01-19
# 2              NaN           NaN  Non-Cancer      2013-01-19
# 3              NaN           NaN  Non-Cancer      2013-06-29
# 4              NaN           NaN  Non-Cancer      2013-06-29
# ...            ...           ...         ...             ...
# 3085           NaN           NaN  Non-Cancer      2019-04-01
# 3086           NaN           NaN  Non-Cancer      2015-06-21
# 3087           NaN           NaN  Non-Cancer      2015-06-21
# 3088           NaN           NaN  Non-Cancer      2016-02-01
# 3089           NaN           NaN  Non-Cancer      2016-02-01
#
#      ImageLateralityFinal view  ...  has_pix_array  category VOILUTFunction  \
# 0                       L   CC  ...          False  no image            NaN
# 1                       L  MLO  ...          False  no image            NaN
# 2                       L  MLO  ...          False  no image            NaN
# 3                       L   CC  ...          False  no image            NaN
# 4                       L  MLO  ...          False  no image            NaN
# ...                   ...  ...  ...            ...       ...            ...
# 3085                    R  MLO  ...          False  no image            NaN
# 3086                    R  MLO  ...          False  no image            NaN
# 3087                    R   CC  ...          False  no image            NaN
# 3088                    R   CC  ...          False  no image            NaN
# 3089                    R  MLO  ...          False  no image            NaN
#
#      WindowCenterWidthExplanation diagnosed_date_anon_year study_date_year  \
# 0                             NaN                     2014            2013
# 1                             NaN                     2014            2013
# 2                             NaN                     2014            2013
# 3                             NaN                     2014            2013
# 4                             NaN                     2014            2013
# ...                           ...                      ...             ...
# 3085                          NaN                     2019            2019
# 3086                          NaN                     2019            2015
# 3087                          NaN                     2019            2015
# 3088                          NaN                     2019            2016
# 3089                          NaN                     2019            2016
#
#       Time_to_Cancer_Years time_to_cancer_group  \
# 0                        1                BC 1Y
# 1                        1                BC 1Y
# 2                        1                BC 1Y
# 3                        1                BC 1Y
# 4                        1                BC 1Y
# ...                    ...                  ...
# 3085                     0                BC 1Y
# 3086                     4                BC 4Y
# 3087                     4                BC 4Y
# 3088                     3                BC 3Y
# 3089                     3                BC 3Y
#
#                                           file_path_dcm years_last_followup
# 0     /storage2/images/cohort_2/10119504/1.2.846.113...                   1
# 1     /storage2/images/cohort_2/10119504/1.2.846.113...                   1
# 2     /storage2/images/cohort_2/10119504/1.2.846.113...                   1
# 3     /storage2/images/cohort_2/10119504/1.2.847.113...                   0
# 4     /storage2/images/cohort_2/10119504/1.2.847.113...                   0
# ...                                                 ...                 ...
# 3085  /storage2/images/cohort_1/99868531/1.2.849.113...                   0
# 3086  /storage2/images/cohort_1/99868531/1.2.840.113...                   3
# 3087  /storage2/images/cohort_1/99868531/1.2.840.113...                   3
# 3088  /storage2/images/cohort_1/99868531/1.2.846.113...                   3
# 3089  /storage2/images/cohort_1/99868531/1.2.846.113...                   3
#
# [3090 rows x 26 columns]

# %%
negative_cases = negative_cases.groupby('patient_id').apply(calculate_negative_followup)

# Combine datasets if needed
all_cases = pd.concat([positive_cases, negative_cases], ignore_index=True)
# Out:
# <ipython-input-8-2326b4459596>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   negative_cases = negative_cases.groupby('patient_id').apply(calculate_negative_followup)

# %%
display(all_cases)
# Out:
#        patient_id           exam_id diagnosed_date_anon  procdate_anon  \
# 0        10119504  5579010047669510          2014-02-10            NaN
# 1        10119504  5579010047669510          2014-02-10            NaN
# 2        10119504  5579010047669510          2014-02-10            NaN
# 3        10119504  9436120411494617          2014-02-10            NaN
# 4        10119504  9436120411494617          2014-02-10            NaN
# ...           ...               ...                 ...            ...
# 52440    99986224  8107409307566891                 NaT            NaN
# 52441    99986224  9061973132112039                 NaT            NaN
# 52442    99986224  9061973132112039                 NaT            NaN
# 52443    99986224  9061973132112039                 NaT            NaN
# 52444    99986224  9061973132112039                 NaT            NaN
#
#        total_L_find  total_R_find       Label study_date_anon  \
# 0               NaN           NaN  Non-Cancer      2013-01-19
# 1               NaN           NaN  Non-Cancer      2013-01-19
# 2               NaN           NaN  Non-Cancer      2013-01-19
# 3               NaN           NaN  Non-Cancer      2013-06-29
# 4               NaN           NaN  Non-Cancer      2013-06-29
# ...             ...           ...         ...             ...
# 52440           NaN           NaN         NaN      2018-05-22
# 52441           NaN           NaN         NaN      2013-04-10
# 52442           NaN           NaN         NaN      2013-04-10
# 52443           NaN           NaN         NaN      2013-04-10
# 52444           NaN           NaN         NaN      2013-04-10
#
#       ImageLateralityFinal view  ...  time_to_cancer_group  \
# 0                        L   CC  ...                 BC 1Y
# 1                        L  MLO  ...                 BC 1Y
# 2                        L  MLO  ...                 BC 1Y
# 3                        L   CC  ...                 BC 1Y
# 4                        L  MLO  ...                 BC 1Y
# ...                    ...  ...  ...                   ...
# 52440                    R  MLO  ...                   NaN
# 52441                    L   CC  ...                   NaN
# 52442                    R   CC  ...                   NaN
# 52443                    L  MLO  ...                   NaN
# 52444                    R  MLO  ...                   NaN
#
#                                            file_path_dcm years_last_followup  \
# 0      /storage2/images/cohort_2/10119504/1.2.846.113...                   1
# 1      /storage2/images/cohort_2/10119504/1.2.846.113...                   1
# 2      /storage2/images/cohort_2/10119504/1.2.846.113...                   1
# 3      /storage2/images/cohort_2/10119504/1.2.847.113...                   0
# 4      /storage2/images/cohort_2/10119504/1.2.847.113...                   0
# ...                                                  ...                 ...
# 52440                                                NaN                   0
# 52441                                                NaN                   5
# 52442                                                NaN                   5
# 52443                                                NaN                   5
# 52444                                                NaN                   5
#
#                                          anon_dicom_path  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 52440  /storage2/images/cohort_1/99986224/1.2.843.113...
# 52441  /storage2/images/cohort_1/99986224/1.2.843.113...
# 52442  /storage2/images/cohort_1/99986224/1.2.843.113...
# 52443  /storage2/images/cohort_1/99986224/1.2.843.113...
# 52444  /storage2/images/cohort_1/99986224/1.2.843.113...
#
#                                            desc asses path_severity side  \
# 0                                           NaN   NaN           NaN  NaN
# 1                                           NaN   NaN           NaN  NaN
# 2                                           NaN   NaN           NaN  NaN
# 3                                           NaN   NaN           NaN  NaN
# 4                                           NaN   NaN           NaN  NaN
# ...                                         ...   ...           ...  ...
# 52440  MG Screen Bilat w/Tomo/CAD Stnd Protocol     N           NaN    R
# 52441              MG Screening Bilateral w/CAD     N           NaN    L
# 52442              MG Screening Bilateral w/CAD     N           NaN    R
# 52443              MG Screening Bilateral w/CAD     N           NaN    L
# 52444              MG Screening Bilateral w/CAD     N           NaN    R
#
#       bside match_level
# 0       NaN         NaN
# 1       NaN         NaN
# 2       NaN         NaN
# 3       NaN         NaN
# 4       NaN         NaN
# ...     ...         ...
# 52440   NaN          []
# 52441   NaN          []
# 52442   NaN          []
# 52443   NaN          []
# 52444   NaN          []
#
# [52445 rows x 33 columns]

# %%
# Save to CSV
all_cases.to_csv('combined_cases_with_followup.csv', index=False)
